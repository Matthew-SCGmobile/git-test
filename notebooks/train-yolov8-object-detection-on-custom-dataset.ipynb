# %%
# 🔥 ม้วนเดียวจบ: ติดตั้ง -> ดูด Data -> เทรน AI -> โหลดลงคอม 🔥

# 1. เช็คการ์ดจอ และ ติดตั้งของที่จำเป็น
# !nvidia-smi
# %pip install ultralytics roboflow

import os
import glob
import time
from google.colab import files
from roboflow import Roboflow
from ultralytics import YOLO

# ==========================================
# 🚨 แก้ไขข้อมูลตรงนี้ก่อนไปนอนนะไอ้สัส! 🚨
# ==========================================
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5Cf00uPB7o5uyPYcRbUm")
project = rf.workspace("a-e0owc").project("knife-detection-bstjz-sd1af")
version = project.version(6)
dataset = version.download("yolov8")

# ==========================================

# 2. ดูด Data จาก Roboflow
print("\n📥 สเต็ป 1: กำลังดูด Data มหาศาลจาก Roboflow...")
rf = Roboflow(api_key=API_KEY)
project = rf.workspace(WORKSPACE_NAME).project(PROJECT_NAME)
version = project.version(VERSION_NUMBER)
dataset = version.download("yolov8")
print(f"✅ โหลด Data เสร็จเรียบร้อย! เก็บไว้ที่: {dataset.location}")

# 3. เริ่มเตาหลอม AI (เทรนด้วย AutoBatch ให้มันรีดพลังสุดปลอก)
print("\n🚀 สเต็ป 2: เริ่มเทรนสมอง AI (ของเยอะแบบนี้ มึงไปนอนได้เลย เดี๋ยวจัดการต่อเอง)...")
model = YOLO('yolo11s.pt')
yaml_path = os.path.join(dataset.location, "data.yaml")

results = model.train(
    data=yaml_path,
    epochs=100,
    imgsz=640,
    batch=-1,         # 🔥 AutoBatch ให้ AI คำนวณแรมการ์ดจอเอง ป้องกันระเบิด!
    device=0,
    plots=True,
    patience=20       # ถ้าย่ำอยู่กับที่ 20 รอบ ตัดจบให้เลย จะได้ไม่เสียเวลา
)

print("\n🎉 สเต็ป 3: เทรนเสร็จแล้วไอ้สัส! โคตรตึง! กำลังแพ็คสมองกลับบ้าน...")

# 4. ค้นหาและบังคับโหลดไฟล์ที่ดีที่สุดลงคอม
list_of_files = glob.glob('/content/runs/detect/train*/weights/best.pt')

if list_of_files:
    latest_file = max(list_of_files, key=os.path.getctime)
    print(f"✅ เจอไฟล์สมองเทพแล้ว: {latest_file}")
    print("⏳ กำลังยิงไฟล์เข้าเครื่องคอมมึง! (ถ้าเน็ตมึงไม่หลุดหรือคอมไม่ Sleep นะสัส!)")

    # สั่งดาวน์โหลดอัตโนมัติ
    files.download(latest_file)
    print("🎉 ดันไฟล์เข้าคิวดาวน์โหลดเรียบร้อย! ฝันดีไอ้สัส!")
else:
    print("❌ ไอ้ชิบหาย! หาไฟล์ best.pt ไม่เจอ! แม่ง Error กลางทางชัวร์ ตื่นมาเช็คด่วน!")
# Out:
# Mon Mar 16 17:20:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
